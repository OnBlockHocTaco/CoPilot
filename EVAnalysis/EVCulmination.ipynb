# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
xl = pd.ExcelFile("SELF-19712 - Monthly pull by trim.xlsx")
df = xl.parse("Sheet1")
Dates = ["2020-05-01", "2020-06-01", "2020-07-01", "2020-08-01", "2020-09-01", "2020-10-01", "2020-11-01",
        "2020-12-01", "2021-01-01", "2021-02-01", "2021-03-01", "2021-04-01"]
CompleteStandardized = []
Month = ["May", "June", "July", "August", "September", "October", "November", "December", "January", "February", "March", "April"]
MonthData = {'Date': Dates,
        'Word': Month}
Months = pd.DataFrame(MonthData)

# %%
#Audi eTron
eTron2016 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2016) & (df["DivisionName"] == "Audi") & (df["ModelName"] == "A3 e-tron") & (df["Trim"] == "Premium") & (df['StockType'] == "used")]
eTron2017 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2017) & (df["DivisionName"] == "Audi") & (df["ModelName"] == "A3 Sportback e-tron") & (df["Trim"] == "Premium") & (df['StockType'] == "used")]
eTron2018 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2018) & (df["DivisionName"] == "Audi") & (df["ModelName"] == "A3 Sportback e-tron") & (df["Trim"] == "Premium") & (df['StockType'] == "used")]
l = []
for D in Dates:
    num2016 = eTron2016.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2017 = eTron2017.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2018 = eTron2018.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    l += [np.average([num2016, num2017, num2018])]
maximum = max(l)
minimum = min(l)
standard = []
for val in l:
    standardized = (val - minimum) / (maximum - minimum)
    standard += [standardized]
CompleteStandardized.append(standard)    


data = {'Date': Dates,
        'Price': standard}
eTron = pd.DataFrame(data)  
eTron.plot.line(x='Date', y='Price')

# %%
#BMW i3
i32015 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2015) & (df["DivisionName"] == "BMW") & (df["ModelName"] == "i3") & (df["Trim"].isnull()) & (df['StockType'] == "used")]
i32016 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2016) & (df["DivisionName"] == "BMW") & (df["ModelName"] == "i3") & (df["Trim"].isnull()) & (df['StockType'] == "used")]
i32017 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2017) & (df["DivisionName"] == "BMW") & (df["ModelName"] == "i3") & (df["Trim"].isnull()) & (df['StockType'] == "used")]
i32018 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2018) & (df["DivisionName"] == "BMW") & (df["ModelName"] == "i3") & (df["Trim"].isnull()) & (df['StockType'] == "used")]
import numpy as np
l = []
for D in Dates:
    num2015 = i32015.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2016 = i32016.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2017 = i32017.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2018 = i32018.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    l += [np.average([num2015, num2016, num2017, num2018])]
maximum = max(l)
minimum = min(l)
standard = []
for val in l:
    standardized = (val - minimum) / (maximum - minimum)
    standard += [standardized]
CompleteStandardized.append(standard)  
    
    
data = {'Date': Dates,
        'Price': standard}
i3 = pd.DataFrame(data)  
i3.plot.line(x='Date', y='Price')

# %%
#Chevrolet Bolt
Bolt2017 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2017) & (df["DivisionName"] == "Chevrolet") & (df["ModelName"] == "Bolt EV") & (df["StockType"] == "used") & (df["Trim"] == "LT")]
Bolt2018 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2018) & (df["DivisionName"] == "Chevrolet") & (df["ModelName"] == "Bolt EV") & (df["StockType"] == "used") & (df["Trim"] == "LT")]
Bolt2019 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2019) & (df["DivisionName"] == "Chevrolet") & (df["ModelName"] == "Bolt EV") & (df["StockType"] == "used") & (df["Trim"] == "LT")]
l = []
for D in Dates:
    num2017 = Bolt2017.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2018 = Bolt2018.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2019 = Bolt2019.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    l += [np.average([num2017, num2018, num2019])]
maximum = max(l)
minimum = min(l)
standard = []
for val in l:
    standardized = (val - minimum) / (maximum - minimum)
    standard += [standardized]
CompleteStandardized.append(standard)      
    
    
data = {'Date': Dates,
        'Price': standard}
Bolt = pd.DataFrame(data)  

Bolt.plot.line(x='Date', y='Price')

# %%
#Kia Niro
Niro2017 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2017) & (df["DivisionName"] == "Kia") & (df["ModelName"] == "Niro") & (df["Trim"] == "LX") & (df['StockType'] == "used")]
Niro2018 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2018) & (df["DivisionName"] == "Kia") & (df["ModelName"] == "Niro") & (df["Trim"] == "LX") & (df['StockType'] == "used")]
Niro2019 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2019) & (df["DivisionName"] == "Kia") & (df["ModelName"] == "Niro") & (df["Trim"] == "LX") & (df['StockType'] == "used")]
Niro2020 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2020) & (df["DivisionName"] == "Kia") & (df["ModelName"] == "Niro") & (df["Trim"] == "LX") & (df['StockType'] == "used")]
l = []
for D in Dates:
    num2017 = Niro2017.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2018 = Niro2018.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2019 = Niro2019.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2020 = 0
    if D == "2020-05-01" or D == "2020-06-01":
        second = Niro2020.loc[(df['ReportDate'] == "2020-08-01")]['avgPrice'].iloc[0]
        num2020 = second
    else:
        num2020 = Niro2020.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    l += [np.average([num2017, num2018, num2019, num2020])]
maximum = max(l)
minimum = min(l)
standard = []
for val in l:
    standardized = (val - minimum) / (maximum - minimum)
    standard += [standardized]
CompleteStandardized.append(standard)  
    
data = {'Date': Dates,
        'Price': standard}
Niro = pd.DataFrame(data)  
Niro.plot.line(x='Date', y='Price')

# %%
#Tesla Model3
Model32017 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2017) & (df["DivisionName"] == "Tesla") & (df["ModelName"] == "Model 3") & (df["Trim"] == "Long Range")]
Model32018 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2018) & (df["DivisionName"] == "Tesla") & (df["ModelName"] == "Model 3") & (df["Trim"] == "Long Range Battery")]
Model32019 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2019) & (df["DivisionName"] == "Tesla") & (df["ModelName"] == "Model 3") & (df["Trim"] == "Standard Range Plus")]
l = []
last2017 = 0
last2018 = 0
last2019 = 0
for D in Dates:
    num2017 = 0;
    num2018 = 0;
    num2019 = 0;
    if D == "2020-09-01":
        num2017 += (last2017 + Model32017.loc[(df['ReportDate'] == "2020-10-01")]['avgPrice'].iloc[0]) / 2
        num2018 += (last2018 + Model32018.loc[(df['ReportDate'] == "2020-10-01")]['avgPrice'].iloc[0]) / 2
        num2019 += (last2019 + Model32019.loc[(df['ReportDate'] == "2020-10-01")]['avgPrice'].iloc[0]) / 2
    else:
        num2017 = Model32017.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
        last2017 = num2017
        num2018 = Model32018.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
        last2018 = num2018
        num2019 = Model32019.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
        last2019 = num2019
    l += [np.average([num2017, num2018, num2019])]
maximum = max(l)
minimum = min(l)
standard = []
for val in l:
    standardized = (val - minimum) / (maximum - minimum)
    standard += [standardized]
CompleteStandardized.append(standard)  

data = {'Date': Dates,
        'Price': standard}
Model3 = pd.DataFrame(data)  
Model3.plot.line(x='Date', y='Price')

# %%
#Tesla ModelS
ModelS2015 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2015) & (df["DivisionName"] == "Tesla") & (df["ModelName"] == "Model S") & (df["Trim"] == "85D")]
ModelS2016 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2016) & (df["DivisionName"] == "Tesla") & (df["ModelName"] == "Model S") & (df["Trim"] == "90D")]
ModelS2017 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2017) & (df["DivisionName"] == "Tesla") & (df["ModelName"] == "Model S") & (df["Trim"] == "100D")]
ModelS2018 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2018) & (df["DivisionName"] == "Tesla") & (df["ModelName"] == "Model S") & (df["Trim"] == "75D")]
l = []
for D in Dates:
    num2015 = ModelS2015.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2016 = ModelS2016.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2017 = ModelS2017.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2018 = ModelS2018.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    l += [np.average([num2015, num2016, num2017, num2018])]
maximum = max(l)
minimum = min(l)
standard = []
for val in l:
    standardized = (val - minimum) / (maximum - minimum)
    standard += [standardized]
CompleteStandardized.append(standard)      
    
data = {'Date': Dates,
        'Price': standard}
ModelS = pd.DataFrame(data)  
ModelS.plot.line(x='Date', y='Price')

# %%
#Tesla ModelX
ModelX2016 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2016) & (df["DivisionName"] == "Tesla") & (df["ModelName"] == "Model X") & (df["Trim"] == "90D") & (df['StockType'] == "used")]
ModelX2017 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2017) & (df["DivisionName"] == "Tesla") & (df["ModelName"] == "Model X") & (df["Trim"] == "75D") & (df['StockType'] == "used")]
ModelX2018 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2018) & (df["DivisionName"] == "Tesla") & (df["ModelName"] == "Model X") & (df["Trim"] == "75D") & (df['StockType'] == "used")]
ModelX2019 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2019) & (df["DivisionName"] == "Tesla") & (df["ModelName"] == "Model X") & (df["Trim"] == "Performance") & (df['StockType'] == "used")]
l = []
for D in Dates:
    num2016 = ModelX2016.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2017 = ModelX2017.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2018 = ModelX2018.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2019 = ModelX2019.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    l += [np.average([num2016, num2017, num2018, num2019])]
maximum = max(l)
minimum = min(l)
standard = []
for val in l:
    standardized = (val - minimum) / (maximum - minimum)
    standard += [standardized]
CompleteStandardized.append(standard)     
data = {'Date': Dates,
        'Price': standard}
ModelX = pd.DataFrame(data)  
ModelX.plot.line(x='Date', y='Price')

# %%
#Nissan Leaf
Leaf2015 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2015) & (df["DivisionName"] == "Nissan") & (df["ModelName"] == "LEAF") & (df["Trim"] == "S") & (df['StockType'] == "used")]
Leaf2016 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2016) & (df["DivisionName"] == "Nissan") & (df["ModelName"] == "LEAF") & (df["Trim"] == "S") & (df['StockType'] == "used")]
Leaf2017 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2017) & (df["DivisionName"] == "Nissan") & (df["ModelName"] == "LEAF") & (df["Trim"] == "S") & (df['StockType'] == "used")]
Leaf2018 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2018) & (df["DivisionName"] == "Nissan") & (df["ModelName"] == "LEAF") & (df["Trim"] == "SV") & (df['StockType'] == "used")]
l = []
for D in Dates:
    num2015 = Leaf2015.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2016 = Leaf2016.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2017 = Leaf2017.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2018 = Leaf2018.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    l += [np.average([num2015, num2016, num2017, num2018])]
maximum = max(l)
minimum = min(l)
standard = []
for val in l:
    standardized = (val - minimum) / (maximum - minimum)
    standard += [standardized]
CompleteStandardized.append(standard) 
data = {'Date': Dates,
        'Price': standard}
Leaf = pd.DataFrame(data)  
Leaf.plot.line(x='Date', y='Price')

# %%
#Porsche Taycan
Taycan2020 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2020) & (df["DivisionName"] == "Porsche") & (df["ModelName"] == "Taycan") & (df["Trim"] == "Turbo") & (df['StockType'] == "used")]
l = []
for D in Dates:
    num2020 = Taycan2020.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    l += [np.average([num2020])]
maximum = max(l)
minimum = min(l)
standard = []
for val in l:
    standardized = (val - minimum) / (maximum - minimum)
    standard += [standardized]
CompleteStandardized.append(standard)     
data = {'Date': Dates,
        'Price': standard}
Taycan = pd.DataFrame(data)  

Taycan.plot.line(x='Date', y='Price')

# %%
#Volkswagen eGolf
eGolf2015 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2015) & (df["DivisionName"] == "Volkswagen") & (df["ModelName"] == "e-Golf") & (df["Trim"] == "SEL Premium") & (df['StockType'] == "used")]
eGolf2016 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2016) & (df["DivisionName"] == "Volkswagen") & (df["ModelName"] == "e-Golf") & (df["Trim"] == "SEL Premium") & (df['StockType'] == "used")]
eGolf2017 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2017) & (df["DivisionName"] == "Volkswagen") & (df["ModelName"] == "e-Golf") & (df["Trim"] == "SEL Premium") & (df['StockType'] == "used")]
eGolf2018 = df.loc[(df['ReportDate'].isin(Dates)) & (df['ModelYear'] == 2018) & (df["DivisionName"] == "Volkswagen") & (df["ModelName"] == "e-Golf") & (df["Trim"] == "SE") & (df['StockType'] == "used")]
l = []
for D in Dates:
    num2015 = eGolf2015.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2016 = eGolf2016.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2017 = eGolf2017.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    num2018 = eGolf2018.loc[(df['ReportDate'] == D)]['avgPrice'].iloc[0]
    l += [np.average([num2015, num2016, num2017, num2018])]
maximum = max(l)
minimum = min(l)
standard = []
for val in l:
    standardized = (val - minimum) / (maximum - minimum)
    standard += [standardized]
CompleteStandardized.append(standard)  
data = {'Date': Dates,
        'Price': standard}
eGolf = pd.DataFrame(data)  
eGolf.plot.line(x='Date', y='Price')

# %%
ev = []
for i in range(len(Dates)):
    evsum = 0
    standardLength = len(CompleteStandardized)
    for standards in CompleteStandardized:
        evsum += standards[i]
    ev.append(evsum / standardLength)    
data = {'Date': Dates,
        'Price': ev}
ElectricVehicles = pd.DataFrame(data)  
ElectricVehicles.plot.line(x='Date', y='Price')

# %%
plt.figure(figsize=(14,6))
plt.title("Average Standardized Selling Price of Electric Vehicles")
lp = sns.lineplot(x = Dates, y = ElectricVehicles["Price"])
lp.set(xlabel='Date', ylabel='Average Standardized Price by Month')
setter = lp.set_xticklabels(Months['Word'])

# %%
EVdata = pd.DataFrame({
    'Month': Dates, 
    'Volkswagen eGolf': eGolf['Price'],
    'Porsche Taycan': Taycan['Price'],
    'Nissan Leaf' : Leaf['Price'],
    'Tesla Model X' : ModelX['Price'],
    'Tesla Model S' : ModelS['Price'],
    'Tesla Model3' : Model3['Price'],
    'Kia Niro' : Niro['Price'],
    'Chevrolet Bolt' : Bolt['Price'],
    'BMW i3' : i3['Price'],
    'Audi eTron' : eTron['Price']
    })
EVdata = EVdata.set_index(["Month"])

plt.figure(figsize=(14,6))
lp = sns.lineplot(data=EVdata, dashes=False)  
setting = lp.set_xticklabels(Months['Word'])
lp.set(ylabel='Standardized Relative Price by Month')
plt.title("Standardized Pricing for Popular Electric Vehicles")
# Out:
# Text(0.5, 1.0, 'Standardized Pricing for Popular Electric Vehicles')
